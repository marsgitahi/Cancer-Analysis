# %% [markdown]
# <a href="https://colab.research.google.com/github/marsgitahi/Cancer-Analysis/blob/main/Cancerbm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Problem Statement**
# To predict or analyze relationships between lifestyle factors (e.g., smoking, alcohol consumption) and cancer outcomes (e.g., incidence rates, death rates) across different countries.

# %% [markdown]
# # **Step 1: Data Loading**

# %%
# Libraries
import pandas as pd

# Data Loading
cp=pd.read_excel("/content/Cancer.xlsx")
cp
# Out:
#     Country or Territory  \
# 0            Afghanistan
# 1                Algeria
# 2             Azerbaijan
# 3                Albania
# 4                Armenia
# ..                   ...
# 202              Réunion
# 203     French Polynesia
# 204           Guadeloupe
# 205                 Guam
# 206           Martinique
#
#     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                    5
# ..                                                 ...
# 202                                            No data
# 203                                            No data
# 204                                            No data
# ...

# %%
# Columns
from tabulate import tabulate

# Get all column names
column_names = cp.columns.tolist()

# Convert column names to a list of lists for tabulate
column_names_table = [[i+1, name] for i, name in enumerate(column_names)]

# Print column names as a table
print(tabulate(column_names_table, headers=["Index", "Column Name"]))
# Out:
#   Index  Column Name
# -------  -----------------------------------------------------------------------------------------------------------------------------------
#       1  Country or Territory
#       2  Cancer deaths attributable to alcohol
#          Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016
#       3  Smoking prevalence male
#          Prevalence (%) of daily smoking for men
#       4  Smoking prevalence female
#          Prevalence (%) of daily smoking for women
#       5  Cancers attributable to infections
#          Proportion of cancers attributable to infections (%), by country
#       6  Obesity prevalence male
#          International variation in the prevalence of obesity, 2016
#       7  Obesity prevalence female
#          International variation in the prevalence of obesity, 2016
#       8  Melanoma skin cancer incidence
#          Age-standardized rate (world) per 100,000, both sexes, 2018
# ...

# %%
# Select Column names that will help anaswer your problem
selected_columns = [
    'Country or Territory',
    'Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016',
    'Smoking prevalence male\nPrevalence (%) of daily smoking for men',
    'Smoking prevalence female\nPrevalence (%) of daily smoking for women',
    'Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country',
    'Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016',
    'Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016',
    'Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018',
    'Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018',
    'Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018',
    'Cervical cancer incidence rates\nAge-standardized rate (world) per 100,000, 2018'
]

# Select the relevant columns from the DataFrame
impt_cp = cp[selected_columns]
impt_cp
# Out:
#     Country or Territory  \
# 0            Afghanistan
# 1                Algeria
# 2             Azerbaijan
# 3                Albania
# 4                Armenia
# ..                   ...
# 202              Réunion
# 203     French Polynesia
# 204           Guadeloupe
# 205                 Guam
# 206           Martinique
#
#     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                    5
# ..                                                 ...
# 202                                            No data
# 203                                            No data
# 204                                            No data
# ...

# %%
# Head
impt_cp.head()
# Out:
#   Country or Territory  \
# 0          Afghanistan
# 1              Algeria
# 2           Azerbaijan
# 3              Albania
# 4              Armenia
#
#   Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                0.5
# 1                                                1.1
# 2                                                3.2
# 3                                                4.9
# 4                                                  5
#
#   Smoking prevalence male\nPrevalence (%) of daily smoking for men  \
# 0                                               21.4
# 1                                               17.5
# 2                                               36.7
# 3                                               40.9
# 4                                               43.5
#
#   Smoking prevalence female\nPrevalence (%) of daily smoking for women  \
# ...

# %%
# Tail
impt_cp.tail()
# Out:
#     Country or Territory  \
# 202              Réunion
# 203     French Polynesia
# 204           Guadeloupe
# 205                 Guam
# 206           Martinique
#
#     Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 202                                            No data
# 203                                            No data
# 204                                            No data
# 205                                            No data
# 206                                            No data
#
#     Smoking prevalence male\nPrevalence (%) of daily smoking for men  \
# 202                                            No data
# 203                                            No data
# 204                                            No data
# 205                                            No data
# 206                                            No data
#
# ...

# %%
# Data Types
impt_cp.dtypes
# Out:
# Country or Territory                                                                                                                     object
# Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016    object
# Smoking prevalence male\nPrevalence (%) of daily smoking for men                                                                         object
# Smoking prevalence female\nPrevalence (%) of daily smoking for women                                                                     object
# Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country                                     object
# Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016                                                      object
# ...

# %%
# Data Structure
impt_cp.shape
# Out:
# (207, 11)

# %%
# Convert selected numeric columns to numeric data type
impt_cp = impt_cp.copy()

# Define the list of numeric columns
numeric_columns=['Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016',
    'Smoking prevalence male\nPrevalence (%) of daily smoking for men',
    'Smoking prevalence female\nPrevalence (%) of daily smoking for women',
    'Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country',
    'Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016',
    'Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016',
    'Lung cancer incidence rates, male\nAge-standardized rate (world) per 100,000, all ages, 2018',
    'Lung cancer incidence rates, female\nAge-standardized rate (world) per 100,000, all ages, 2018',
    'Cancer survivors\nEstimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018',
     'Cervical cancer incidence rates\nAge-standardized rate (world) per 100,000, 2018'
]

impt_cp[numeric_columns] = impt_cp[numeric_columns].apply(pd.to_numeric, errors='coerce')
impt_cp[numeric_columns]
# Out:
#      Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                  5.0
# ..                                                 ...
# 202                                                NaN
# 203                                                NaN
# 204                                                NaN
# 205                                                NaN
# 206                                                NaN
#
#      Smoking prevalence male\nPrevalence (%) of daily smoking for men  \
# 0                                                 21.4
# 1                                                 17.5
# ...

# %%
numericc=impt_cp[numeric_columns]
numericc
# Out:
#      Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                  5.0
# ..                                                 ...
# 202                                                NaN
# 203                                                NaN
# 204                                                NaN
# 205                                                NaN
# 206                                                NaN
#
#      Smoking prevalence male\nPrevalence (%) of daily smoking for men  \
# 0                                                 21.4
# 1                                                 17.5
# ...

# %% [markdown]
# # **Step 2: Data Cleaning**

# %%
# Duplicates
impt_cp.duplicated().sum()
# Out:
# 3

# %%
#Removing Duplicates
impt_cp.drop_duplicates(inplace=True)

#Checking if there are still duplicates
duplicates=impt_cp.duplicated().sum()
print(duplicates)
# Out:
# 0

# %%
# Missing Values
impt_cp.isnull().sum()
# Out:
# Country or Territory                                                                                                                      0
# Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016    23
# Smoking prevalence male\nPrevalence (%) of daily smoking for men                                                                         18
# Smoking prevalence female\nPrevalence (%) of daily smoking for women                                                                     16
# Cancers attributable to infections\nProportion of cancers attributable to infections (%), by country                                     23
# Obesity prevalence male\nInternational variation in the prevalence of obesity, 2016                                                      16
# Obesity prevalence female\nInternational variation in the prevalence of obesity, 2016                                                    16
# ...

# %%
# Removing missing values
clean_cp=impt_cp.dropna()
clean_cp
# Out:
#     Country or Territory  \
# 0            Afghanistan
# 1                Algeria
# 2             Azerbaijan
# 3                Albania
# 4                Armenia
# ..                   ...
# 189               Cyprus
# 190              Lebanon
# 191           Luxembourg
# 192                Malta
# 193  Trinidad and Tobago
#
#      Cancer deaths attributable to alcohol\nProportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                  5.0
# ..                                                 ...
# 189                                                4.8
# 190                                                1.5
# 191                                                6.7
# ...

# %%
# Ensure consistency in column names
clean_cp.columns = clean_cp.columns.str.replace('\n', '_')  # Replace newline characters with underscores
clean_cp.columns
# Out:
# Index(['Country or Territory',
#        'Cancer deaths attributable to alcohol_Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016',
#        'Smoking prevalence male_Prevalence (%) of daily smoking for men',
#        'Smoking prevalence female_Prevalence (%) of daily smoking for women',
#        'Cancers attributable to infections_Proportion of cancers attributable to infections (%), by country',
#        'Obesity prevalence male_International variation in the prevalence of obesity, 2016',
#        'Obesity prevalence female_International variation in the prevalence of obesity, 2016',
#        'Lung cancer incidence rates, male_Age-standardized rate (world) per 100,000, all ages, 2018',
#        'Lung cancer incidence rates, female_Age-standardized rate (world) per 100,000, all ages, 2018',
#        'Cancer survivors_Estimated number of cancer survivors diagnosed within the past five years per 100,000 population, both sexes, 2018',
# ...

# %%
# Convert data types
numericc= clean_cp.columns[1:]  # Exclude 'Country or Territory'
clean_cp[numericc] = clean_cp[numericc].astype(float)
clean_cp[numericc]
# Out:
# <ipython-input-69-966d185aead6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_cp[numericc] = clean_cp[numericc].astype(float)
#      Cancer deaths attributable to alcohol_Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                  5.0
# ..                                                 ...
# 189                                                4.8
# 190                                                1.5
# ...

# %%
# Confirm the changes
print(clean_cp.dtypes)
# Out:
# Country or Territory                                                                                                                     object
# Cancer deaths attributable to alcohol_Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016    float64
# Smoking prevalence male_Prevalence (%) of daily smoking for men                                                                         float64
# Smoking prevalence female_Prevalence (%) of daily smoking for women                                                                     float64
# Cancers attributable to infections_Proportion of cancers attributable to infections (%), by country                                     float64
# Obesity prevalence male_International variation in the prevalence of obesity, 2016                                                      float64
# ...

# %%
# Check for missing values
missing_values = clean_cp.isnull().sum()
print(missing_values)
# Out:
# Country or Territory                                                                                                                    0
# Cancer deaths attributable to alcohol_Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016    0
# Smoking prevalence male_Prevalence (%) of daily smoking for men                                                                         0
# Smoking prevalence female_Prevalence (%) of daily smoking for women                                                                     0
# Cancers attributable to infections_Proportion of cancers attributable to infections (%), by country                                     0
# Obesity prevalence male_International variation in the prevalence of obesity, 2016                                                      0
# Obesity prevalence female_International variation in the prevalence of obesity, 2016                                                    0
# ...

# %% [markdown]
# # **Step 3: Exploratory Data Analysis and Visualization**

# %%
# Summary Statistics
clean_cp.describe()
# Out:
#        Cancer deaths attributable to alcohol_Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# count                                         169.000000
# mean                                            5.353254
# std                                             2.962987
# min                                             0.200000
# 25%                                             2.900000
# 50%                                             5.300000
# 75%                                             7.400000
# max                                            14.500000
#
#        Smoking prevalence male_Prevalence (%) of daily smoking for men  \
# count                                         169.000000
# mean                                           24.056805
# std                                            11.435584
# min                                             4.400000
# 25%                                            14.700000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize the distributions of cancer prevalence and mortality rates
plt.figure(figsize=(10, 6))
sns.histplot(data=clean_cp, x='Cancer deaths attributable to alcohol_Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016', kde=True, color='blue')
plt.title('Distribution of Cancer Death Rate')
plt.xlabel('Cancer Survivors Rate (per 100,000 population)')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histograms for each numeric column
numeric_columns = clean_cp[numericc].columns
plt.figure(figsize=(16, 10))
for i, column in enumerate(numeric_columns, 1):
    if i <= 4:  # Plot only first 4 pairwise histograms
        plt.subplot(2, 2, i)
        sns.histplot(clean_cp[numericc][column], kde=True)
        plt.title(f'Histogram of {column}')
plt.tight_layout()
plt.show()

# %%
#Plotting histogram for the remaining numerical columns
numeric_columns = clean_cp[numericc].columns
plt.figure(figsize=(16, 10))
for i, column in enumerate(numeric_columns, 1):
    if i > 4:  # Plot remaining histograms
        plt.subplot(3, 3, i-4)
        sns.histplot(clean_cp[numericc][column], kde=True)
        plt.title(f'Histogram of {column}')
plt.tight_layout()
plt.show()

# %%
# Plot pairwise scatter plots
plt.figure(figsize=(12, 8))
sns.pairplot(clean_cp[numericc])
plt.title('Pairwise Scatter Plots of Health Indicators and Cancer Rates')
plt.show()

# %%
# Plot box plots for each numeric column
plt.figure(figsize=(16, 10))
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(3, 4, i)
    sns.boxplot(y=clean_cp[numericc][column])
    plt.title(f'Box Plot of {column}')
plt.tight_layout()
plt.show()

# %%
# Plot box plots for each numeric column to check for outliers
plt.figure(figsize=(12, 8))
sns.boxplot(data=clean_cp[numericc], orient='h')
plt.title('Box Plots of Health Indicators and Cancer Rates')
plt.xlabel('Values')
plt.show()

# %%
# Calculate IQR for each numeric column
Q1 = clean_cp[numericc].quantile(0.25)
Q3 = clean_cp[numericc].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter dataset to remove outliers
clean_cp_no_outliers = clean_cp.loc[~((clean_cp[numericc] < lower_bound) | (clean_cp[numericc] > upper_bound)).any(axis=1)]

# Print shape before and after removing outliers
print("Shape before removing outliers:", clean_cp.shape)
print("Shape after removing outliers:", clean_cp_no_outliers.shape)
# Out:
# Shape before removing outliers: (169, 11)
# Shape after removing outliers: (145, 11)

# %%
clean_cp_no_outliers
# Out:
#     Country or Territory  \
# 0            Afghanistan
# 1                Algeria
# 2             Azerbaijan
# 3                Albania
# 4                Armenia
# ..                   ...
# 189               Cyprus
# 190              Lebanon
# 191           Luxembourg
# 192                Malta
# 193  Trinidad and Tobago
#
#      Cancer deaths attributable to alcohol_Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# 0                                                  0.5
# 1                                                  1.1
# 2                                                  3.2
# 3                                                  4.9
# 4                                                  5.0
# ..                                                 ...
# 189                                                4.8
# 190                                                1.5
# 191                                                6.7
# ...

# %%
# Generate summary statistics for cleaned_df_no_outliers
summary_stats_no_outliers = clean_cp_no_outliers.describe()
summary_stats_no_outliers
# Out:
#        Cancer deaths attributable to alcohol_Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016  \
# count                                         145.000000
# mean                                            5.160690
# std                                             2.910715
# min                                             0.200000
# 25%                                             2.700000
# 50%                                             5.000000
# 75%                                             7.200000
# max                                            11.800000
#
#        Smoking prevalence male_Prevalence (%) of daily smoking for men  \
# count                                         145.000000
# mean                                           24.317931
# std                                            11.210224
# min                                             4.400000
# 25%                                            14.200000
# ...

# %%
# Using dataframe summary_stats_no_outliers:

# Create a histogram for each column in the dataframe
import matplotlib.pyplot as plt
for column in summary_stats_no_outliers.columns:
    plt.figure()
    plt.hist(summary_stats_no_outliers[column])
    plt.title(column)
    plt.show()

# %%
# Visualize histograms for each numeric column after removing outliers
plt.figure(figsize=(16, 10))
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(3, 4, i)
    sns.histplot(clean_cp_no_outliers[column], kde=True)
    plt.title(f'Histogram of {column}')
plt.tight_layout()
plt.show()

# %%
# Drop the 'Country or Territory' column
clean_cp_no_outliers_numeric = clean_cp_no_outliers.drop(columns=['Country or Territory'])

# Explore correlations between different health indicators and cancer rates
correlation_matrix = clean_cp_no_outliers_numeric.corr()

# Plot correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Health Indicators and Cancer Rates')
plt.show()

# %% [markdown]
# # **Step 4: Modelling**

# %%
# Libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix

# %% [markdown]
# # **Regresssion**

# %%
# Setting up feature matrix (X) and target vector (y) for regression
X_regression = clean_cp_no_outliers_numeric.drop(columns=['Cancer deaths attributable to alcohol_Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016'])
y_regression = clean_cp_no_outliers_numeric['Cancer deaths attributable to alcohol_Proportion (%) of cancer deaths caused by alcohol drinking in men ages 15 years or older, 2016']


# Split the data for regression and classification
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(X_regression, y_regression, test_size=0.2, random_state=42)


# 1. Linear Regression
lin_reg = LinearRegression()
lin_reg.fit(X_train_reg, y_train_reg)
y_pred_lin = lin_reg.predict(X_test_reg)
mse_lin = mean_squared_error(y_test_reg, y_pred_lin)
r2_lin = r2_score(y_test_reg, y_pred_lin)


# 2. Random Forest Regression
rf_reg = RandomForestRegressor(random_state=42)
rf_reg.fit(X_train_reg, y_train_reg)
y_pred_rf = rf_reg.predict(X_test_reg)
mse_rf = mean_squared_error(y_test_reg, y_pred_rf)
r2_rf = r2_score(y_test_reg, y_pred_rf)

# %%
# Get feature importances
feature_importances = rf_reg.feature_importances_

# Visualize feature importances
plt.figure(figsize=(10, 6))
plt.barh(X_train_reg.columns, feature_importances)
plt.xlabel('Feature Importance')
plt.ylabel('Features')
plt.title('Feature Importance Scores')
plt.show()

# %% [markdown]
# # **Classification**

# %%
# Setting up feature matrix (X) and target vector (y) for classification
X_classification = clean_cp_no_outliers_numeric.drop(columns=['Cervical cancer incidence rates_Age-standardized rate (world) per 100,000, 2018'])
y_classification = clean_cp_no_outliers_numeric[ 'Cervical cancer incidence rates_Age-standardized rate (world) per 100,000, 2018']


# Binarizing classification target (for classification model)
clean_cp_no_outliers_numeric['Cervical_Cancer_High_Low'] = (clean_cp_no_outliers_numeric[ 'Cervical cancer incidence rates_Age-standardized rate (world) per 100,000, 2018'] >clean_cp_no_outliers_numeric[ 'Cervical cancer incidence rates_Age-standardized rate (world) per 100,000, 2018'].median()).astype(int)
y_classification = clean_cp_no_outliers_numeric['Cervical_Cancer_High_Low']



# Split the data for regression and classification
X_train_class, X_test_class, y_train_class, y_test_class = train_test_split(X_regression, y_classification, test_size=0.2, random_state=42)

# Initialize the LabelEncoder
le = LabelEncoder()
le.fit(y_test_class)

# 1. Logistic Regression
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train_class, y_train_class)
y_pred_log = log_reg.predict(X_test_class)
accuracy_log = accuracy_score(y_test_class, y_pred_log)

# 2. Random Forest Classifier
rf_clf = RandomForestClassifier(random_state=42)
rf_clf.fit(X_train_class, y_train_class)
y_pred_rf_class = rf_clf.predict(X_test_class)
accuracy_rf_class = accuracy_score(y_test_class, y_pred_rf_class)

# %% [markdown]
# # **Step 5: Evaluation**

# %%
# Evaluation for Regression
models = ['Linear Regression', 'Random Forest']
predictions = [y_pred_lin, y_pred_rf]
results = {}

for model, pred in zip(models, predictions):
    mse = mean_squared_error(y_test_reg, pred)
    r2 = r2_score(y_test_reg, pred)
    results[model] = {'MSE': mse, 'R2 Score': r2}

results_df = pd.DataFrame(results).T
print(results_df)
# Out:
#                         MSE  R2 Score
# Linear Regression  6.952118  0.292983
# Random Forest      6.010365  0.388758

# %% [markdown]
# Random Forest outperforms Linear Regression based on both MSE and R².
#
#  Random Forest is better at reducing prediction error (lower MSE) and better at explaining variance (higher R²).
#
# The relatively low R² scores (0.293 and 0.389) for both models indicate that neither model is explaining the majority of the variance in the target variable.

# %%
# Evaluation for Classification
classification_models = ['Logistic Regression', 'Random Forest']
classification_predictions = [y_pred_log, y_pred_rf_class, ]
classification_results = {}

for model, pred in zip(classification_models, classification_predictions):
    report = classification_report(y_test_class, pred, output_dict=True)
    classification_results[model] = {
        'Precision': report['weighted avg']['precision'],
        'Recall': report['weighted avg']['recall'],
        'F1 Score': report['weighted avg']['f1-score']
    }

classification_results_df = pd.DataFrame(classification_results).T
print(classification_results_df)
# Out:
#                      Precision    Recall  F1 Score
# Logistic Regression   0.931034  0.931034  0.931034
# Random Forest         1.000000  1.000000  1.000000

# %% [markdown]
# Random Forest fit the model perfectly at 100% followed by Logistic Regression at 93%

# %% [markdown]
# # **Visualizatiion of the results**

# %%
# Regression Predictions vs Actual
plt.figure(figsize=(12, 6))
for model, pred in zip(models, predictions):
    plt.scatter(y_test_reg, pred, label=model)
plt.plot([y_test_reg.min(), y_test_reg.max()], [y_test_reg.min(), y_test_reg.max()], 'k--', lw=2)
plt.xlabel('Actual House Price')
plt.ylabel('Predicted House Price')
plt.title('Regression Predictions vs Actual')
plt.legend()
plt.show()

# %% [markdown]
# For both Linear Regression and Random Forest, majority of their points are scattered far from the dashed line. This indicates that the models' predictions deviate significantly from the actual values in many cases. This suggests that the models may have limited predictive accuracy for this particular dataset.

# %%
#Classification Predictions vs Actual

# Confusion Matrix for each classifier
models = ['Logistic Regression', 'Random Forest']
predictions = [y_pred_log, y_pred_rf_class]

# Create subplots for each confusion matrix
fig, axes = plt.subplots(2, 1, figsize=(12, 12))
axes = axes.flatten()

for ax, model, pred in zip(axes, models, predictions):
    cm = confusion_matrix(y_test_class, pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax,
                xticklabels=le.classes_, yticklabels=le.classes_)
    ax.set_title(f'Confusion Matrix - {model}')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Logistic Regression**
#
# 19 instances were predicted correctly as high and 8 instances were predicted correctly as low
#
# **Random Forest**
#
# 20 instances were predicted correctly as high and 9 instances were predicted correctly as low

# %% [markdown]
# # **Step 6: Conclusion**
#
# The regression models; Linear Regression nd Random Forest have limited predictive ability in predicting Cancer deaths attributable to alcohol consumption.
#
# The classification models; Logistic Regression and Random Forest fit the model perfectly by correctly predicting the high and low instances for Cervical cancer incidence rates.
